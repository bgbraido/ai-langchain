# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# Out:
# Requirement already satisfied: langchain==0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.local/lib/python3.12/site-packages (from langchain==0.3.0) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (2.0.41)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (3.12.9)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (0.3.8)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (2.11.5)
# Requirement already satisfied: requests<3,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain==0.3.0) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain==0.3.0) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.20.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.3.0) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.0) (3.2.2)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.3.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Requirement already satisfied: langchain-groq==0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-groq==0.2.0) (0.26.0)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-groq==0.2.0) (0.3.63)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (2.11.5)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/codespace/.local/lib/python3.12/site-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.126 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (24.2)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (3.10)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.126->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (2.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# # Aula 5: Utilizando LangChain para acessar o Llama 3

# %% [markdown]
# Você já deve ter percebido que existem diversos empresas diferentes criando modelos de linguagem (llms). O mais conhecido hoje é o GPT desenvolvido pela OpenAI, mas podemos citar diversos outros como o Gemini do Google, o Claud da Anthropic, o Llama da Meta, etc.
#
# É importante entendermos que a biblioteca LangChain não constrói modelos de linguagem próprios, mas se especializa em fornecer uma interface padronizada para acessar e integrar modelos de diferentes provedores. Em vez de oferecer modelos próprios, LangChain facilita a conexão e o uso de LLMs de terceiros, como OpenAI, Hugging Face, entre outros. Isso permite que os desenvolvedores construam aplicações complexas de processamento de linguagem natural utilizando uma variedade de modelos e fontes de dados, sem se preocupar com as especificidades de cada provedor individualmente. Em essência, LangChain atua como uma camada de abstração que unifica o acesso e a interação com diversos modelos de linguagem.
#
# Nesta aula vamos ensinar como utilizar o LangChain para acessar os principais modelos gratuitos utilizando a Groq!

# %% [markdown]
# ## Craindo uma api key
#
# Primeiro, vamos criar uma conta na Groq e gerar uma chave de acesso a sua conta (também chamada de API KEY). Para isso, siga os seguintes passos:
# - Crie uma conta na plataforma da [Groq](https://console.groq.com/)
# - Acesse a página de criação de [api keys](https://console.groq.com/keys)
# - Clique em "Create API key"
# - Defina um nome e clique em "Submit"
# - Copie o valor da chave

# %%
api_key = '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'

# %% [markdown]
# ## Fazendo a primeira chamada ao modelo

# %%
import os

os.environ['GROQ_API_KEY'] = api_key

# %%
from langchain_groq import ChatGroq

chat = ChatGroq(model='llama-3.3-70b-versatile')

# %%
response = chat.invoke("Who are you?")

# %%
print(response.content)
# Out:
# I'm an artificial intelligence model known as Llama. Llama stands for "Large Language Model Meta AI."
